# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA

import warnings

# %%
warnings.filterwarnings('ignore')

# %%
# Plotly and Cufflinks setup

#!pip install plotly
#!pip install cufflinks
#!pip install chart_studio

import chart_studio.plotly as py
import plotly.graph_objs as go

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
print(__version__) #requires version >= 1.9.0

import cufflinks as cf

#for Notebooks
init_notebook_mode(connected = True)

#for offline use
cf.go_offline()
# Out:
# 5.1.0
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Loading Data

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#path = "/content/drive/MyDrive/8.Pakistan_Largest_Ecommerce_Dataset/Pakistan Largest Ecommerce Dataset.csv"

# %%
#Enter file path
path = "./Pakistan Largest Ecommerce Dataset.csv"

# %%
df = pd.read_csv(path,  parse_dates = ["M-Y"], low_memory = False, na_values = ["NaN", 'NaT', ' -   '])

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(5)
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  \
# 0       1950.0    100147443    Women's Fashion                    \N
# 1        240.0    100147444  Beauty & Grooming                    \N
# 2       2450.0    100147445    Women's Fashion                    \N
# 3         60.0    100147446  Beauty & Grooming           R-FSD-52352
# 4       1110.0    100147447            Soghaat                    \N
#
#    discount_amount payment_method Working Date BI Status      MV     Year  \
# 0              0.0            cod     7/1/2016     #REF!   1,950   2016.0
# 1              0.0            cod     7/1/2016     Gross     240   2016.0
# 2              0.0            cod     7/1/2016     Gross   2,450   2016.0
# 3            300.0            cod     7/1/2016       Net     360   2016.0
# 4              0.0            cod     7/1/2016     Valid   1,110   2016.0
#
#    Month Customer Since        M-Y    FY  Customer ID  Unnamed: 21  \
# 0    7.0         2016-7 2016-07-01  FY17          1.0          NaN
# 1    7.0         2016-7 2016-07-01  FY17          2.0          NaN
# 2    7.0         2016-7 2016-07-01  FY17          3.0          NaN
# 3    7.0         2016-7 2016-07-01  FY17          4.0          NaN
# 4    7.0         2016-7 2016-07-01  FY17          5.0          NaN
#
#    Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN

# %%
len(df)
# Out:
# 1048575

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447349 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
#  14   MV                    582292 non-null  object
#  15  Year                   584524 non-null  float64
#  16  Month                  584524 non-null  float64
#  17  Customer Since         584513 non-null  object
#  18  M-Y                    584524 non-null  datetime64[ns]
#  19  FY                     584524 non-null  object
#  20  Customer ID            584513 non-null  float64
#  21  Unnamed: 21            0 non-null       float64
#  22  Unnamed: 22            0 non-null       float64
#  23  Unnamed: 23            0 non-null       float64
#  24  Unnamed: 24            0 non-null       float64
#  25  Unnamed: 25            0 non-null       float64
# dtypes: datetime64[ns](1), float64(13), object(12)
# memory usage: 208.0+ MB

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ### Droping off Un-necessary Columns

# %%
df.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %% [markdown]
# #### Droping Columns = ['Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25']

# %%
drop_columns_0 = df.columns[-5:]
drop_columns_0
# Out:
# Index(['Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25'],
#       dtype='object')

# %%
df.drop(drop_columns_0, axis = 1, inplace = True)

# %% [markdown]
# #### Droping Columns "items_id", "created_at", "increment_id", "sales_commission_code", "Working Date" , "BI Status" , "Year", "Month", "FY"

# %%
drop_columns_1 = ["item_id", "created_at", "increment_id", "sales_commission_code", "Working Date" , "BI Status" , "Year", "Month", "Customer Since", "FY"]

# %%
df.drop(drop_columns_1, axis = 1, inplace = True)

# %% [markdown]
# ### Re arranging Columns

# %%
df = df[['Customer ID', 'sku', 'category_name_1', 'status', 'qty_ordered',  'price', 'grand_total',
       'discount_amount', ' MV ', 'payment_method', 'M-Y']]

# %% [markdown]
# #### Check For Missing Data

# %%
missing = pd.DataFrame(df.isnull().sum())
missing.transpose()
# Out:
#    Customer ID     sku  category_name_1  status  qty_ordered   price  \
# 0       464062  464071           464215  464066       464051  464051
#
#    grand_total  discount_amount     MV   payment_method     M-Y
# 0       464051           464051  466283          464051  464051

# %%
total_missing_values = df.isnull().sum().sum()
total_missing_values
# Out:
# 5107003

# %% [markdown]
# ### Droping off Missing Values Rows

# %%
df.dropna(axis = 0, how = 'any', inplace = True)

# %%
#Checking again for missing values
missing = pd.DataFrame(df.isnull().sum())
missing.transpose()
# Out:
#    Customer ID  sku  category_name_1  status  qty_ordered  price  grand_total  \
# 0            0    0                0       0            0      0            0
#
#    discount_amount   MV   payment_method  M-Y
# 0                0     0               0    0

# %%
#Checking again
total_missing_values = df.isnull().sum().sum()
total_missing_values
# Out:
# 0

# %%
#Checking again for missing values in ' MV ' col
df[' MV '].isnull().sum()#.sum()
# Out:
# 0

# %%
df.head(5)
# Out:
#    Customer ID                                                sku  \
# 0          1.0                                  kreations_YI 06-L
# 1          2.0  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...
# 2          3.0                                 Ego_UP0017-999-MR0
# 3          4.0                                     kcc_krone deal
# 4          5.0                                        BK7010400AG
#
#      category_name_1          status  qty_ordered   price  grand_total  \
# 0    Women's Fashion        complete          1.0  1950.0       1950.0
# 1  Beauty & Grooming        canceled          1.0   240.0        240.0
# 2    Women's Fashion        canceled          1.0  2450.0       2450.0
# 3  Beauty & Grooming        complete          1.0   360.0         60.0
# 4            Soghaat  order_refunded          2.0   555.0       1110.0
#
#    discount_amount      MV  payment_method        M-Y
# 0              0.0   1,950             cod 2016-07-01
# 1              0.0     240             cod 2016-07-01
# 2              0.0   2,450             cod 2016-07-01
# 3            300.0     360             cod 2016-07-01
# 4              0.0   1,110             cod 2016-07-01

# %%
len(df)
# Out:
# 582100

# %%
df['M-Y'].unique()
# Out:
# array(['2016-07-01T00:00:00.000000000', '2016-08-01T00:00:00.000000000',
#        '2016-09-01T00:00:00.000000000', '2016-10-01T00:00:00.000000000',
#        '2016-11-01T00:00:00.000000000', '2016-12-01T00:00:00.000000000',
#        '2017-01-01T00:00:00.000000000', '2017-02-01T00:00:00.000000000',
#        '2017-03-01T00:00:00.000000000', '2017-04-01T00:00:00.000000000',
#        '2017-05-01T00:00:00.000000000', '2017-06-01T00:00:00.000000000',
#        '2017-07-01T00:00:00.000000000', '2017-08-01T00:00:00.000000000',
#        '2017-09-01T00:00:00.000000000', '2017-10-01T00:00:00.000000000',
#        '2017-11-01T00:00:00.000000000', '2017-12-01T00:00:00.000000000',
#        '2018-02-01T00:00:00.000000000', '2018-01-01T00:00:00.000000000',
#        '2018-03-01T00:00:00.000000000', '2018-04-01T00:00:00.000000000',
#        '2018-05-01T00:00:00.000000000', '2018-06-01T00:00:00.000000000',
#        '2018-07-01T00:00:00.000000000', '2018-08-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
df['M-Y'].nunique()
# Out:
# 26

# %%
df['M-Y'].value_counts()
# Out:
# 2017-11-01    83726
# 2016-11-01    71482
# 2018-03-01    41755
# 2017-05-01    34651
# 2018-05-01    27719
# 2018-02-01    26827
# 2017-08-01    25070
# 2017-04-01    21675
# 2017-03-01    19528
# 2017-06-01    19451
# 2017-07-01    19195
# 2017-10-01    17410
# 2017-12-01    15540
# 2016-09-01    15432
# 2018-06-01    14651
# 2016-12-01    13425
# 2017-01-01    13170
# 2016-10-01    13119
# 2018-01-01    12689
# 2018-04-01    12057
# 2018-08-01    11873
# 2017-02-01    11860
# 2016-08-01    11524
# 2018-07-01    11019
# 2016-07-01     8826
# 2017-09-01     8426
# Name: M-Y, dtype: int64

# %% [markdown]
# ### Looking for 0 (zeros) in integer or float value columns

# %%
df[df['qty_ordered'] == 0]['qty_ordered'].value_counts()
# Out:
# Series([], Name: qty_ordered, dtype: int64)

# %%
df[df['price'] == 0]['price'].value_counts()
# Out:
# Series([], Name: price, dtype: int64)

# %%
df[df[' MV '] == '0'][' MV '].value_counts()
# Out:
# Series([], Name:  MV , dtype: int64)

# %%
df[df['grand_total'] == 0]['grand_total'].value_counts()
# Out:
# 0.0    9465
# Name: grand_total, dtype: int64

# %%
#found 9465 cells containing 0.0 in column 'grand_total'
#replace 0.0 from corresponding values of ' MV ' column

# %%
def replace_zeros(x, y):
    if x == 0:
        return y
    else: 
        return x

# %%
df.columns
# Out:
# Index(['Customer ID', 'sku', 'category_name_1', 'status', 'qty_ordered',
#        'price', 'grand_total', 'discount_amount', ' MV ', 'payment_method',
#        'M-Y'],
#       dtype='object')

# %%
df['grand_total'] = df.apply(lambda z: replace_zeros(z['grand_total'], z[' MV ']), axis = 1)

# %%
#Checking again
df[df['grand_total'] == 0]['grand_total'].value_counts()
# Out:
# Series([], Name: grand_total, dtype: int64)

# %% [markdown]
# ### Now DataFrame Without 0(Zeros) and Null Values

# %%
df.head(5)
# Out:
#    Customer ID                                                sku  \
# 0          1.0                                  kreations_YI 06-L
# 1          2.0  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...
# 2          3.0                                 Ego_UP0017-999-MR0
# 3          4.0                                     kcc_krone deal
# 4          5.0                                        BK7010400AG
#
#      category_name_1          status  qty_ordered   price grand_total  \
# 0    Women's Fashion        complete          1.0  1950.0      1950.0
# 1  Beauty & Grooming        canceled          1.0   240.0       240.0
# 2    Women's Fashion        canceled          1.0  2450.0      2450.0
# 3  Beauty & Grooming        complete          1.0   360.0        60.0
# 4            Soghaat  order_refunded          2.0   555.0      1110.0
#
#    discount_amount      MV  payment_method        M-Y
# 0              0.0   1,950             cod 2016-07-01
# 1              0.0     240             cod 2016-07-01
# 2              0.0   2,450             cod 2016-07-01
# 3            300.0     360             cod 2016-07-01
# 4              0.0   1,110             cod 2016-07-01

# %%
len(df)
# Out:
# 582100

# %%
df.columns
# Out:
# Index(['Customer ID', 'sku', 'category_name_1', 'status', 'qty_ordered',
#        'price', 'grand_total', 'discount_amount', ' MV ', 'payment_method',
#        'M-Y'],
#       dtype='object')

# %% [markdown]
# **Task 6: Predict and Forecasting**

# %%
df_no_of_orders_cat = pd.crosstab(df['M-Y'], df['category_name_1']) #, margins = True
df_no_of_orders_cat
# Out:
# category_name_1  Appliances  Beauty & Grooming  Books  Computing  \
# M-Y
# 2016-07-01              378               2425     22        214
# 2016-08-01              339               1846    165        203
# 2016-09-01             1226               1405     37        487
# 2016-10-01              616               1388     73        237
# 2016-11-01             6279               5754     89       2616
# 2016-12-01              860               1080     52        317
# 2017-01-01              636                880     39        292
# 2017-02-01              314                685     43        194
# 2017-03-01             1452               1239     97        448
# 2017-04-01              890               1265     53        343
# 2017-05-01             3338               1382     40        889
# 2017-06-01             1044               1482     63        305
# 2017-07-01              639               1178     45        568
# 2017-08-01             1423               1660     36        726
# 2017-09-01              400                696     24        170
# 2017-10-01              671               1089     22        677
# 2017-11-01            14495               5003     44       2635
# 2017-12-01             1751               1833      7        437
# 2018-01-01             1237               1262     16        370
# 2018-02-01             2926               1098     12        677
# 2018-03-01             2895               1267     36        871
# 2018-04-01              986                873     43        312
# 2018-05-01             4274               1685     28        821
# 2018-06-01             1341               1191     36        402
# 2018-07-01              806                780     33        318
# 2018-08-01             1105                958     37        373
#
# category_name_1  Entertainment  Health & Sports  Home & Living  Kids & Baby  \
# M-Y
# 2016-07-01                  64              181            389          160
# 2016-08-01                  91              371            427          509
# 2016-09-01                 851              433            760          461
# 2016-10-01                 291              532            619          578
# 2016-11-01                1892             1972           2984         1116
# 2016-12-01                 333              671            451          591
# 2017-01-01                 267              511            358          497
# 2017-02-01                 200              561            724          360
# 2017-03-01                 691              495           1014          758
# 2017-04-01                 371              490            952          660
# 2017-05-01                1963             1286           1555         1380
# 2017-06-01                 453              532            768         1125
# 2017-07-01                 571              533            763         1150
# 2017-08-01                 951              555            832          683
# 2017-09-01                 456              289            341          229
# 2017-10-01                1312              307            472          384
# 2017-11-01                5654             1054           6022         1802
# 2017-12-01                 289              321            957          635
# 2018-01-01                 485              483            728          422
# 2018-02-01                2605              630           1173          760
# 2018-03-01                2058             1031            808          422
# 2018-04-01                 284              965            723          480
# 2018-05-01                2192             1275            808          432
# 2018-06-01                 483              821            596          307
# 2018-07-01                 410              785            595          283
# 2018-08-01                1101              417            585          257
#
# category_name_1  Men's Fashion  Mobiles & Tablets  Others  School & Education  \
# M-Y
# 2016-07-01                1003                820      35                 177
# 2016-08-01                2587               1792      54                 241
# 2016-09-01                1264               3318     355                  94
# 2016-10-01                1954               1724     163                 177
# 2016-11-01               15719              11837    1117                 311
# 2016-12-01                2840               2786      89                 203
# 2017-01-01                2022               3045     120                 162
# 2017-02-01                2079               3124     109                  71
# 2017-03-01                2554               4218     141                 224
# 2017-04-01                3284               3539     102                 147
# 2017-05-01                6809               5876     202                  88
# 2017-06-01                3935               2720     290                 104
# 2017-07-01                1942               5058     202                 209
# 2017-08-01                3681               4254     106                 186
# 2017-09-01                1632               1967      54                  75
# 2017-10-01                2267               3956    1600                  52
# 2017-11-01               16280              19385     342                 143
# 2017-12-01                2931               2393     103                  32
# 2018-01-01                1573               2654      78                  77
# 2018-02-01                3658               5737    4017                 143
# 2018-03-01                3417               5914   19237                 158
# 2018-04-01                1681               2217     187                  75
# 2018-05-01                2168               7350     259                  78
# 2018-06-01                1774               3757      96                  74
# 2018-07-01                1246               3443      65                  91
# 2018-08-01                1506               2512      65                  86
#
# category_name_1  Soghaat  Superstore  Women's Fashion    \N
# M-Y
# 2016-07-01          1746          12              469   731
# 2016-08-01          1843         251              628   177
# 2016-09-01          1771         993              967  1010
# 2016-10-01          2754         242              966   805
# 2016-11-01          6382        4889             5710  2815
# 2016-12-01          1748         237              885   282
# 2017-01-01          1706        1012             1282   341
# 2017-02-01          1029         677             1488   202
# 2017-03-01          1183         361             4432   221
# 2017-04-01          1155        5580             2668   176
# 2017-05-01          1954        2626             4941   322
# 2017-06-01          1364        3159             1840   267
# 2017-07-01          1040        3581             1565   151
# 2017-08-01          1159        5043             3576   199
# 2017-09-01           532         339             1214     8
# 2017-10-01           642        1825             2132     2
# 2017-11-01          1064        2089             7615    99
# 2017-12-01           908         662             2267    14
# 2018-01-01           661         952             1691     0
# 2018-02-01           328        1101             1962     0
# 2018-03-01           339        1178             2124     0
# 2018-04-01           340         639             2252     0
# 2018-05-01          1197        2340             2812     0
# 2018-06-01           642        1711             1420     0
# 2018-07-01           257         700             1207     0
# 2018-08-01           257        1240             1374     0

# %%
df[df['M-Y'] == '2016-08-01']['category_name_1'].value_counts()
# Out:
# Men's Fashion         2587
# Beauty & Grooming     1846
# Soghaat               1843
# Mobiles & Tablets     1792
# Women's Fashion        628
# Kids & Baby            509
# Home & Living          427
# Health & Sports        371
# Appliances             339
# Superstore             251
# School & Education     241
# Computing              203
# \N                     177
# Books                  165
# Entertainment           91
# Others                  54
# Name: category_name_1, dtype: int64

# %%
df_no_of_orders_cat.plot(figsize = (12, 8), legend = True)
plt.show()

# %%
# layout = go.Layout(title = "Number of Orders Per Category", 
#                    xaxis = {'title': 'Month-Year'}, 
#                    yaxis = {'title': 'No. of Orders'}, 
#                    showlegend = True, 
#                    width = 1000, 
#                    height = 600,)

# df_no_of_orders_cat.iplot(kind = 'line', layout = layout)

# %%
# import plotly.express as px

# fig = px.line(df_no_of_orders_cat)

# fig.update_xaxes(title_text='Month-Year')
# fig.update_yaxes(title_text='No. of Orders')

# fig.show()

# %%
df = df_no_of_orders_cat

# %%
df.head(2)
# Out:
# category_name_1  Appliances  Beauty & Grooming  Books  Computing  \
# M-Y
# 2016-07-01              378               2425     22        214
# 2016-08-01              339               1846    165        203
#
# category_name_1  Entertainment  Health & Sports  Home & Living  Kids & Baby  \
# M-Y
# 2016-07-01                  64              181            389          160
# 2016-08-01                  91              371            427          509
#
# category_name_1  Men's Fashion  Mobiles & Tablets  Others  School & Education  \
# M-Y
# 2016-07-01                1003                820      35                 177
# 2016-08-01                2587               1792      54                 241
#
# category_name_1  Soghaat  Superstore  Women's Fashion   \N
# M-Y
# 2016-07-01          1746          12              469  731
# 2016-08-01          1843         251              628  177

# %%
#df['Appliances']

# %%
df_new = df["Men's Fashion"]

# %%
df_new.plot(figsize = (12, 8), legend = True)
plt.show()

# %%
df.index
# Out:
# DatetimeIndex(['2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01',
#                '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01',
#                '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01',
#                '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01',
#                '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01',
#                '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01',
#                '2018-07-01', '2018-08-01'],
#               dtype='datetime64[ns]', name='M-Y', freq=None)

# %% [markdown]
# ### Determine the rolling statistics

# %%
rolmean = df_new.rolling(window = 12).mean()
rolstd = df_new.rolling(window = 12).std()

# %%
#rolmean, rolstd

# %% [markdown]
# ### Plot rolling statistics

# %%
plt.figure(figsize = (10, 6))
orig = plt.plot(df_new, color = 'blue', label = 'Original')
mean = plt.plot(rolmean, color = 'red', label = 'Rolling Mean')
std = plt.plot(rolstd, color = 'green', label = 'Rolling Std')
plt.legend(loc = 'best')
plt.title("Rolling Mean & Standard Deviation")
plt.show(block = False)

# %% [markdown]
# ### Perform Dickey-Fuller Test

# %%
# Need to have p-value around 0.5 or less to have data stationary

# %%
from statsmodels.tsa.stattools import adfuller

# %%
print("Results of Diceky-Fuller Test:\n")

dftest = adfuller(df_new, autolag = 'AIC')

dfoutput = pd.Series(dftest[0:4], index = ['Test Statistics', 'p-Value', '#Lags Used', 'No. of Obeservations Used'])

for key, value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value

dfoutput
# Out:
# Results of Diceky-Fuller Test:
# Test Statistics              -5.110690
# p-Value                       0.000013
# #Lags Used                    0.000000
# No. of Obeservations Used    25.000000
# Critical Value (1%)          -3.723863
# Critical Value (5%)          -2.986489
# Critical Value (10%)         -2.632800
# dtype: float64

# %% [markdown]
# ### Estimate the Trend

# %%
#to make data stationary it depends on data sometime you need to take log of data, square of data, or cube of data
#in this case we already have stationary data as seen in 'Dickey-Fuller Test' and in the plot of 'Rolling Statistics'
#we are doing following steps only for illustration

# %%
plt.figure(figsize = (10, 6))
data_logScale = np.log(df_new)
plt.plot(data_logScale)
plt.show()

# %%
data_logScale
# Out:
# M-Y
# 2016-07-01    6.910751
# 2016-08-01    7.858254
# 2016-09-01    7.142037
# 2016-10-01    7.577634
# 2016-11-01    9.662625
# 2016-12-01    7.951559
# 2017-01-01    7.611842
# 2017-02-01    7.639642
# 2017-03-01    7.845416
# 2017-04-01    8.096817
# 2017-05-01    8.826001
# 2017-06-01    8.277666
# 2017-07-01    7.571474
# 2017-08-01    8.210940
# 2017-09-01    7.397562
# 2017-10-01    7.726213
# 2017-11-01    9.697693
# 2017-12-01    7.983099
# 2018-01-01    7.360740
# 2018-02-01    8.204672
# 2018-03-01    8.136518
# 2018-04-01    7.427144
# 2018-05-01    7.681560
# 2018-06-01    7.480992
# 2018-07-01    7.127694
# 2018-08-01    7.317212
# Name: Men's Fashion, dtype: float64

# %% [markdown]
# ### Calculate Moving Average with the Same Window

# %%
plt.figure(figsize = (10, 6))
movingAverage = data_logScale.rolling(window = 12).mean()
movingSTD = data_logScale.rolling(window = 12).std()
plt.plot(data_logScale, color = 'blue')
plt.plot(movingAverage, color = 'red', label = 'Moving Average')
plt.plot(movingSTD, color = 'green', label = 'Moving STD')
plt.legend(loc = 'best')
plt.title('Moving Average and Moving STD Or Plotting with log of Data')
plt.show()

# %%
movingAverage
# Out:
# M-Y
# 2016-07-01         NaN
# 2016-08-01         NaN
# 2016-09-01         NaN
# 2016-10-01         NaN
# 2016-11-01         NaN
# 2016-12-01         NaN
# 2017-01-01         NaN
# 2017-02-01         NaN
# 2017-03-01         NaN
# 2017-04-01         NaN
# 2017-05-01         NaN
# 2017-06-01    7.950020
# 2017-07-01    8.005081
# 2017-08-01    8.034471
# 2017-09-01    8.055765
# 2017-10-01    8.068146
# 2017-11-01    8.071069
# 2017-12-01    8.073697
# 2018-01-01    8.052772
# 2018-02-01    8.099858
# 2018-03-01    8.124116
# 2018-04-01    8.068310
# 2018-05-01    7.972940
# 2018-06-01    7.906550
# 2018-07-01    7.869569
# 2018-08-01    7.795092
# Name: Men's Fashion, dtype: float64

# %% [markdown]
# ### Calculate difference b/w Log Scale Data and Moving Average

# %%
data_LogScale_Minus_movingAverage = data_logScale - movingAverage
data_LogScale_Minus_movingAverage

#Remove NaN Values
data_LogScale_Minus_movingAverage.dropna(inplace = True)
data_LogScale_Minus_movingAverage = pd.DataFrame(data_LogScale_Minus_movingAverage)
data_LogScale_Minus_movingAverage
# Out:
#             Men's Fashion
# M-Y
# 2017-06-01       0.327646
# 2017-07-01      -0.433607
# 2017-08-01       0.176469
# 2017-09-01      -0.658203
# 2017-10-01      -0.341934
# 2017-11-01       1.626624
# 2017-12-01      -0.090598
# 2018-01-01      -0.692032
# 2018-02-01       0.104814
# 2018-03-01       0.012402
# 2018-04-01      -0.641166
# 2018-05-01      -0.291380
# 2018-06-01      -0.425558
# 2018-07-01      -0.741875
# 2018-08-01      -0.477879

# %% [markdown]
# ### Creating a function to perform test on data to check its stationarity and plot of 'Rolling statistics' and 'Dickey-Fuller Test'

# %%
#this step is the copy of above steps, just putting all together in a function

# %%
from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries):
    
    # Determine Rolling Statistics
    
    average = timeseries.rolling(window = 12).mean()
    std = timeseries.rolling(window = 12).std()
    
    # Plot Rolling Statistics
    
    plt.figure(figsize = (10, 6))
    plt.plot(timeseries, color = 'blue')
    plt.plot(average, color = 'red', label = 'Average')
    plt.plot(std, color = 'green', label = 'STD')
    plt.legend(loc = 'best')
    plt.title('Average and STD with Data')
    plt.show()
    
    # Perform Dickey-Fuller Test
    
    print("\n")
    print("Results of Dickey-Fuller Test: \n")
    dftest = adfuller(timeseries, autolag = 'AIC')

    dfoutput = pd.Series(dftest[0:4], index = ['Test Statistics', 'p-Value', '#Lags Used', 'No. of Obeservations Used'])

    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    
    return dfoutput

# %%
# pass original data or log of data or square/cube of data
# data either in Series or DataFrame
test_stationarity(data_LogScale_Minus_movingAverage)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistics             -0.516223
# p-Value                      0.888812
# #Lags Used                   5.000000
# No. of Obeservations Used    9.000000
# Critical Value (1%)         -4.473135
# Critical Value (5%)         -3.289881
# Critical Value (10%)        -2.772382
# dtype: float64

# %%
test_stationarity(data_logScale)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistics              -4.640863
# p-Value                       0.000109
# #Lags Used                    0.000000
# No. of Obeservations Used    25.000000
# Critical Value (1%)          -3.723863
# Critical Value (5%)          -2.986489
# Critical Value (10%)         -2.632800
# dtype: float64

# %%
test_stationarity(df_new)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistics              -5.110690
# p-Value                       0.000013
# #Lags Used                    0.000000
# No. of Obeservations Used    25.000000
# Critical Value (1%)          -3.723863
# Critical Value (5%)          -2.986489
# Critical Value (10%)         -2.632800
# dtype: float64

# %%
test_stationarity(df_new)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistics              -5.110690
# p-Value                       0.000013
# #Lags Used                    0.000000
# No. of Obeservations Used    25.000000
# Critical Value (1%)          -3.723863
# Critical Value (5%)          -2.986489
# Critical Value (10%)         -2.632800
# dtype: float64

# %%
#Write reasons which data you are using

# As Seen from above results, we have increasing value of p-value, therefore our original data or data_logScale was sufficient enough to preceed further since it had less p-value
# We are using data_logScale in this case

# %% [markdown]
# ### Calculate Weighted Average of Time Series

# %% [markdown]
# #### Reason: To see the Trends present in Time Series

# %%
exponentialDecayWeightedAverage = data_logScale.ewm(halflife = 12, min_periods = 0, adjust = True).mean()

plt.figure(figsize = (10, 6))
plt.plot(data_logScale, color = 'blue')
plt.plot(exponentialDecayWeightedAverage, color = 'red')
plt.show()

# %%
# The red line in plot above shows data has slightly increased trend

# %% [markdown]
# ### Calculate diff b/w logScale and exponentialDecayWeightedAverage

# %%
data_logScale_Minus_exponentialDecayWeightedAverage = data_logScale - exponentialDecayWeightedAverage

# %% [markdown]
# ### Test Stationarity

# %%
test_stationarity(data_logScale_Minus_exponentialDecayWeightedAverage)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistics               1.361203
# p-Value                       0.996931
# #Lags Used                    9.000000
# No. of Obeservations Used    16.000000
# Critical Value (1%)          -3.924019
# Critical Value (5%)          -3.068498
# Critical Value (10%)         -2.673893
# dtype: float64

# %% [markdown]
# ### Forecasting

# %%
# Now we know that our data is stationary

# %%
# Now we will shift the values into time series so that we can use it in the forecasting

# %%
# Subtract the value of Mean from the actual value

# %%
# Here we have taken lag of one or just shifted values by 1
data_shifted = data_logScale - data_logScale.shift()

plt.figure(figsize = (10, 6))
plt.plot(data_shifted)
plt.show()

# %%
# ARIMA MODEL

# It has 3 (three) models in it
# 1) AR = Auto Regressive Model
# 2) MA = Moving Average Model
# 3) I = Integration

# It takes 3 (three) parameters
# P, Q, D
# D=1 (since we shifted by 1)
# Calculation of P, Q in later steps

# %%
data_shifted.values
# Out:
# array([        nan,  0.94750339, -0.71621761,  0.43559726,  2.08499162,
#        -1.71106612, -0.33971693,  0.02779989,  0.20577375,  0.25140143,
#         0.72918307, -0.54833438, -0.70619251,  0.63946608, -0.8133782 ,
#         0.32865111,  1.97147999, -1.7145937 , -0.62235904,  0.84393193,
#        -0.06815358, -0.70937412,  0.25441623, -0.2005682 , -0.35329846,
#         0.18951871])

# %%
# Drop Any NaN values
data_shifted.dropna(inplace = True)

# %%
test_stationarity(data_shifted)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistics             -6.954150e+00
# p-Value                      9.523988e-10
# #Lags Used                   1.000000e+00
# No. of Obeservations Used    2.300000e+01
# Critical Value (1%)         -3.752928e+00
# Critical Value (5%)         -2.998500e+00
# Critical Value (10%)        -2.638967e+00
# dtype: float64

# %%
# Output in above plot is quite flat
# So here you Null_Hypothesis or the augmented 'Dickey-Fuller Test' we take the Null Hypotheis is rejected and hence we can say that time series is stationary now

# %%
# Now lets see the componets of time series

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
time_series = data_logScale
decomposition = seasonal_decompose(time_series, model = 'additive')

observed = decomposition.observed # Original
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot 

# plt.figure(figsize = (10, 6))
# plt.subplot(411)
# plt.plot(observed, color = 'blue', label = 'Observed')
# plt.legend(loc = 1)


# plt.subplot(412)
# plt.plot(trend, color = 'black', label = 'Trend')
# plt.legend(loc = 1)


# plt.subplot(413)
# plt.plot(seasonal, color = 'green', label = 'Seasonal')
# plt.legend(loc = 1)


# plt.subplot(414)
# plt.plot(residual, color = 'yellow', label = 'Residual')
# plt.legend(loc = 1)

# plt.tight_layout()
# plt.show()

# %%
# Plot 
lst_time_series_decompostion = [observed, trend, seasonal, residual]
str_lst = ['Observed', 'Trend', 'Seasonal', 'Residual']
mycolor = ['Black', 'Purple', 'Green', 'Red', 'Blue', 'Orange', 'Grey', 'Violet']

for i in range(len(lst_time_series_decompostion)):
    
    layout = go.Layout(title = "Time Series-Decomposed: " + str_lst[i], 
                   xaxis = {'title': 'Month-Year'}, 
                   #yaxis = {'title': ''}, 
                   showlegend = True, 
                   width = 700, 
                   height = 300)
    
    lst_time_series_decompostion[i].iplot(kind = 'line', layout = layout, color = mycolor[i])

# %%
# Check noise if its stationary or not

# %%
decomposedLogData = residual
decomposedLogData.dropna(inplace = True)
test_stationarity(decomposedLogData)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistics              -3.539762
# p-Value                       0.007023
# #Lags Used                    0.000000
# No. of Obeservations Used    13.000000
# Critical Value (1%)          -4.068854
# Critical Value (5%)          -3.127149
# Critical Value (10%)         -2.701730
# dtype: float64

# %% [markdown]
# ### Plot ACF and PACF Graphs

# %%
#### ACF will give Q
#### PACF will give P

# %%
# from statsmodels.tsa.stattools import acf, pacf

# lag_acf = acf(data_shifted, nlags = 11) #nlag must be less than the half of dataset
# lag_pacf = pacf(data_shifted, nlags = 11, method ='ols')

# # --Plot ACF and PACF Graphs--

# fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))
# fig.suptitle('')

# # Plot ACF Graph

# ax1.plot(lag_acf)
# ax1.axhline(y = 0, linestyle = '--', color = 'grey')
# ax1.axhline(y = -1.96/np.sqrt(len(data_shifted)), linestyle = '--', color = 'grey')
# ax1.axhline(y = 1.96/np.sqrt(len(data_shifted)), linestyle = '--', color = 'grey')
# ax1.set_title("Auto Correlation")

# # Plot PACF Graph

# ax2.plot(lag_pacf)
# ax2.axhline(y = 0, linestyle = '--', color = 'grey')
# ax2.axhline(y = -1.96/np.sqrt(len(data_shifted)), linestyle = '--', color = 'grey')
# ax2.axhline(y = 1.96/np.sqrt(len(data_shifted)), linestyle = '--', color = 'grey')
# ax2.set_title("Partial Auto Correlation")

# plt.tight_layout()
# plt.show()

# %%
from statsmodels.tsa.stattools import acf, pacf

lag_acf = acf(data_shifted, nlags = 11) #nlag must be less than the half of dataset
lag_pacf = pacf(data_shifted, nlags = 11, method ='ols')

lag_acf = pd.DataFrame(lag_acf)
lag_pacf = pd.DataFrame(lag_pacf)

# Plot

lag_acf_pacf = [lag_acf, lag_pacf]
lst_lag_acf_pacf = ['ACF', 'PACF']
mycolor = ['Black', 'Purple', 'Green', 'Red', 'Blue', 'Orange', 'Grey', 'Violet']

for i in range(len(lag_acf_pacf)):
    
    layout = go.Layout(title = lst_lag_acf_pacf[i], 
                   #xaxis = {'title': 'Month-Year'}, 
                   #yaxis = {'title': ''}, 
                   showlegend = True, 
                   width = 700, 
                   height = 500, hovermode = 'closest' )
    
    lag_acf_pacf [i].iplot(kind = 'line', layout = layout, color = mycolor[i])

# %%
# Now look for x-axis value when y = 0 
# in both graphs values on x-axis are 1, therefore
# P, Q = 1 (alsmost)

# %% [markdown]
# ### ARIMA Model

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
## AR Model

# %%
model = ARIMA(data_logScale, order = (0, 1, 1)) #p = 0, d = 1, q = 1
results_AR = model.fit(disp = -1)

plt.figure(figsize = (10, 5))
plt.plot(data_shifted)
plt.plot(results_AR.fittedvalues, color = 'red')
plt.title('Residual Sum of Squares: %.4f'% sum((results_AR.fittedvalues - data_shifted)**2))
plt.tight_layout()
plt.show()

# %%
# ideal Rss = 1.0292
# RSS value in this case is quite high

# %%
## MA Model

model = ARIMA(data_logScale, order = (1, 1, 0)) #p = 0, d = 1, q = 0
results_MA = model.fit(disp = -1)

plt.figure(figsize = (10, 5))
plt.plot(data_shifted)
plt.plot(results_MA.fittedvalues, color = 'red')
plt.title('Residual Sum of Squares: %.4f'% sum((results_MA.fittedvalues - data_shifted)**2))
plt.tight_layout()
plt.show()

# %%
# ARIMA Model
model = ARIMA(data_logScale, order = (2, 1, 1)) #p = 1, d = 1, q = 1
results_ARIMA = model.fit(disp = -1)

plt.figure(figsize = (10, 5))
plt.plot(data_shifted)
plt.plot(results_ARIMA.fittedvalues, color = 'red')
plt.title('Residual Sum of Squares: %.4f'% sum((results_ARIMA.fittedvalues - data_shifted)**2))
plt.tight_layout()
plt.show()

# %%
# Combined RSS must be less
# in this case RSS too high in any case
# which is trouble

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy = True)
predictions_ARIMA_diff.head()
# Out:
# M-Y
# 2016-08-01    0.004364
# 2016-09-01   -0.291365
# 2016-10-01   -0.155882
# 2016-11-01    0.303622
# 2016-12-01   -1.165771
# dtype: float64

# %%
# Convert to Cummulative Sum
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
predictions_ARIMA_diff_cumsum.head()
# Out:
# M-Y
# 2016-08-01    0.004364
# 2016-09-01   -0.287000
# 2016-10-01   -0.442882
# 2016-11-01   -0.139261
# 2016-12-01   -1.305031
# dtype: float64

# %%
data_logScale.index
# Out:
# DatetimeIndex(['2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01',
#                '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01',
#                '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01',
#                '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01',
#                '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01',
#                '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01',
#                '2018-07-01', '2018-08-01'],
#               dtype='datetime64[ns]', name='M-Y', freq=None)

# %%
type(data_logScale)
# Out:
# pandas.core.series.Series

# %%
predictions_ARIMA = pd.Series(data_logScale)

# %%
predictions_ARIMA = predictions_ARIMA.add(predictions_ARIMA_diff_cumsum, fill_value = 0)
predictions_ARIMA.head()
# Out:
# M-Y
# 2016-07-01    6.910751
# 2016-08-01    7.862619
# 2016-09-01    6.855036
# 2016-10-01    7.134752
# 2016-11-01    9.523365
# dtype: float64

# %%
# Since we took the log earlier, therefore convert it back
predictions_ARIMA = np.exp(predictions_ARIMA)

# %%
plt.figure(figsize = (10, 5))
plt.plot(df_new, color = 'blue')
plt.plot(predictions_ARIMA, color = 'orange')
plt.tight_layout()
plt.show()

# %%
len(data_logScale)
# Out:
# 26

# %%
data_logScale
# Out:
# M-Y
# 2016-07-01    6.910751
# 2016-08-01    7.858254
# 2016-09-01    7.142037
# 2016-10-01    7.577634
# 2016-11-01    9.662625
# 2016-12-01    7.951559
# 2017-01-01    7.611842
# 2017-02-01    7.639642
# 2017-03-01    7.845416
# 2017-04-01    8.096817
# 2017-05-01    8.826001
# 2017-06-01    8.277666
# 2017-07-01    7.571474
# 2017-08-01    8.210940
# 2017-09-01    7.397562
# 2017-10-01    7.726213
# 2017-11-01    9.697693
# 2017-12-01    7.983099
# 2018-01-01    7.360740
# 2018-02-01    8.204672
# 2018-03-01    8.136518
# 2018-04-01    7.427144
# 2018-05-01    7.681560
# 2018-06-01    7.480992
# 2018-07-01    7.127694
# 2018-08-01    7.317212
# Name: Men's Fashion, dtype: float64

# %%
plt.figure(figsize = (10, 5))
results_ARIMA.plot_predict(start = 1, end = 25)
plt.tight_layout()
plt.show() 
#results_ARIMA.forecast(steps = 100)


# start = 24 # which is the index position in time series
#end = 24 + 3 # 3 is no. of data points for future

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0
